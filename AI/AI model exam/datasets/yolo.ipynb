# %%
# !pip install ultralytics==8.1.34

from roboflow import Roboflow
rf = Roboflow(api_key="qFMi5amNqkO91zqFocDg")
project = rf.workspace("work-wr3ct").project("beeanalytics")
version = project.version(1)
dataset = version.download("yolov8", "./datasets")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# Dependency ultralytics==8.0.196 is required but found version=8.1.34, to fix: `pip install ultralytics==8.0.196`

# %% [markdown]
# ### Train model locally

# %%
from ultralytics import YOLO

# %%
from ultralytics import YOLO

def main():
    model = YOLO(model="yolov8s.pt")
    model.train(data="D:\Downloads\Howest\Semester 2\Project_one\BeeAnalysis\BeeAnalytics-1\datasets\data.yaml", epochs=1, imgsz=640, verbose=True, batch=8)
    model.val()
    model.export()
if __name__ == '__main__':
    main()
# Out:
# Ultralytics YOLOv8.1.34 🚀 Python-3.11.5 torch-2.1.2+cpu CPU (12th Gen Intel Core(TM) i7-12700H)
# ...

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Load model

# %%
# Load your trained model
model = YOLO("./runs/detect/train/weights/best.pt")

# %% [markdown]
# ### Prediction
# Default ultralytics visualization.<br>
# The output can look different depending if your model originates from roboflow or is trained locally.

# %%
from IPython.display import Image
Image("assignment_image_5.jpg")

# %%
# Make a prediction

path = "assignment_image_5.jpg"
result = model.predict(path)[0]
result.save("prediction_default.jpg")

from IPython.display import Image
Image("prediction_default.jpg")
# Out:
# image 1/1 d:\Downloads\Howest\Semester 2\Project_one\BeeAnalysis\BeeAnalytics-1\datasets\assignment_image_5.jpg: 480x640 4 Drones, 20 Workers, 171.0ms
# Speed: 4.0ms preprocess, 171.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)

# %% [markdown]
# ### Count the instances from a class

# %%
# !pip install supervision
import supervision as sv

print(model.names)
def get_keys_from_value(d, val):
    return [k for k, v in d.items() if v == val]

detections = sv.Detections.from_ultralytics(result)
detections = detections[detections.class_id == get_keys_from_value(model.names, 'Drone')] # if necessary replace by your own class
print("Amount of drones: ",len(detections))
# Out:
# ...
# {0: 'Drone', 1: 'Worker'}
# Amount of drones:  4

# %% [markdown]
# ### Create a simple interface with gradio
# https://www.gradio.app/

# %%
# !pip install gradio
import PIL.Image as Image
import gradio as gr

from ultralytics import ASSETS

def predict_image(img, conf_threshold, iou_threshold):
    results = model.predict(
        source=img,
        conf=conf_threshold,
        iou=iou_threshold,
        show_labels=True,
        show_conf=True,
        imgsz=640,
        agnostic_nms=True
    )

    for r in results:
        im_array = r.plot()
        im = Image.fromarray(im_array[..., ::-1])

    result = model.predict(img)
    result = result[0] if isinstance(result, list) else result 
    detections = sv.Detections.from_ultralytics(result)
    detections = detections[detections.class_id == get_keys_from_value(model.names, 'Drone')]

    print(results)
    return im, {len(detections)}


iface = gr.Interface(
    fn=predict_image,
    inputs=[
        gr.Image(type="pil", label="Upload Image"),
        gr.Slider(minimum=0, maximum=1, value=0.25, label="Confidence threshold"),
        gr.Slider(minimum=0, maximum=1, value=0.45, label="IoU threshold")
    ],
    outputs=[gr.Image(type="pil", label="Result"), gr.Textbox(label="Amount of drones")],
    title="Ultralytics Gradio",
    description="Upload images for inference. The Ultralytics YOLOv8n model is used by default.",
    theme = gr.themes.Monochrome()

)

if __name__ == '__main__':
    iface.launch()
# Out:
# ...
# Running on local URL:  http://127.0.0.1:7861
#
# To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7861/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
